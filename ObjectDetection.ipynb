# %% [markdown]
# <a href="https://colab.research.google.com/github/NorahAlShaikhMubarak/ObjectDetection/blob/master/ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import libs

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive

# %% [markdown]
# # Read image and Show

# %%
img_path = '/content/drive/My Drive/imagedetection'
img = cv2.imread(os.path.join(img_path,'notes.png'))
plt.imshow(img)
plt.show()

# %% [markdown]
# # Convert BGR to HSV

# %%
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(hsv)
plt.show()

# %% [markdown]
# # Set Range HSV of Target and draw contours

# %%
lower_green = np.array([119,27,45]) 
upper_green = np.array([208,255,255]) 
mask = cv2.inRange(hsv,lower_green,upper_green)
contours, hierarchy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img,contours,-1,(0,255,0),10)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Create contours of image

# %%
contours, hierarchy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
n = len(contours)
for i in range(0,n):
  cnt = contours[i]
  per = cv2.arcLength(cnt,True)
  print('per = %.0f'%(per)) 
  if per > 4145:
    x,y,w,h = cv2.boundingRect(cnt)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),20)
plt.axis("off")
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# per = 1104
